# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
colors = np.random.rand(92)

# %%
df = pd.read_csv("training_set.csv")
df.head()
# Out:
#    Impurity.Percent Impurity.Type      I    II  III   IV     V   Temp
# 0              2.69             A  103.9  14.4  9.5  5.0  49.9  31.42
# 1              3.15             A  105.5  14.6  9.7  5.0  50.1  33.51
# 2              3.24             A  106.1  14.6  9.7  5.0  50.0  35.45
# 3              3.32             A  108.5  14.6  9.6  4.9  50.1  32.60
# 4              3.56             A  107.1  14.4  9.3  5.0  48.6  30.53

# %%
df.columns
colors
# Out:
# array([0.94583047, 0.49691632, 0.43850175, 0.78269484, 0.69285404,
#        0.17913055, 0.46146439, 0.35551038, 0.77798094, 0.48613635,
#        0.70606402, 0.07720559, 0.2066591 , 0.42442244, 0.16390261,
#        0.81344167, 0.93411058, 0.07210685, 0.15854046, 0.18382152,
#        0.32509205, 0.94319945, 0.59074347, 0.5170484 , 0.63352218,
#        0.40449297, 0.87430625, 0.42922829, 0.73149807, 0.10953098,
#        0.95715437, 0.42727607, 0.53822171, 0.50338089, 0.51740439,
#        0.57165397, 0.13129184, 0.75290819, 0.83676736, 0.23397063,
#        0.90253049, 0.28949018, 0.96789325, 0.6999939 , 0.51902427,
#        0.2208305 , 0.23473226, 0.21246372, 0.61864914, 0.46332785,
#        0.32177977, 0.99565413, 0.9410958 , 0.97730651, 0.53767791,
#        0.20395888, 0.71235381, 0.63170885, 0.47157058, 0.56790728,
#        0.89593143, 0.49089346, 0.01447379, 0.44599915, 0.08494752,
#        0.79737662, 0.07454546, 0.93801569, 0.64395561, 0.42291025,
# ...

# %%
X = df[['I', 'II', 'III', 'IV', 'V','Temp']]
y = df['Impurity.Type']

# %%
lda = LinearDiscriminantAnalysis()
lda_t = lda.fit_transform(X,y)
lda_df = pd.DataFrame(lda_t)
lda_final = pd.concat([lda_df,y],axis = 'columns')
fig,ax=plt.subplots(1,figsize=(20,8))
sns.scatterplot(data=lda_final, x=0,y=1,hue='Impurity.Type',ax=ax)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
lda.explained_variance_ratio_
# Out:
# array([0.3445496 , 0.31186578, 0.17516736, 0.13424487, 0.03272824,
#        0.00144415])

# %%
plt.bar(x=[1,2,3,4,5,6],height = lda.explained_variance_ratio_)
plt.xlabel('Eigen Vector')
plt.ylabel('Variance Ratio')
# Out:
# Text(0, 0.5, 'Variance Ratio')

# %%
lda.coef_.shape
# Out:
# (13, 6)

# %%
plt.xlabel('LD1')
plt.ylabel('LD2')
plt.scatter(lda_t[:,0],lda_t[:,1],cmap='rainbow',edgecolors='r',c=colors)
